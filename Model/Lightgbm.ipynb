# %%
import pandas as pd
import numpy as np
import gc

import os
import sys
sys.path.append("../")

from Feature.feature import Feature
import Tool.config as config

from sklearn.metrics import log_loss
from sklearn import preprocessing
import xgboost as xgb
import lightgbm as lgb
import matplotlib.pyplot as plt

# %%
data = pd.read_pickle(config.data_prefix_path + 'data.pkl')

# %%
# 还有一种方法，将config.CATEGORICAL_COLS都作为类别特征
object_features = ["predict_category_1","predict_category_2","predict_category_0",
                    "predict_property_0","predict_property_1","predict_property_2",
                    "property_1","property_0","property_2",
                    "category_0",
                    'hour_and_category_1',
                    'category_cross_0', 'category_cross_1', 'category_cross_2',
                    ]

# %%
cat_features = ['user_gender_id','user_occupation_id',"category_1","category_2",'hour']

# %%
features = [c for c in data.columns if c not in ['is_trade', 'instance_id','index',
                                            'context_id', 'time', 'day','context_timestamp',
                                            'property_list','category_list','property_predict_list','category_predict_list',
                                            'item_category_list', 'item_property_list', 'predict_category_property',
                                            'user_id','item_id','item_brand_id','item_city_id','user_id','shop_id',
                                            ]
            and c not in object_features]
target = ['is_trade']

# %%
labelEncoding = preprocessing.LabelEncoder()
data['predict_category_0'] = data['predict_category_0'].apply(lambda x:np.nan if x == '-1' else x)
for col in cat_features:
    data[col] = labelEncoding.fit_transform(data[col].astype(str))

# %%
train = data[data.is_trade.notnull()]
test = data[data.is_trade.isnull()]
del data
gc.collect()
# Out:
# 182

# %%
print(train.shape)
print(test.shape)
# Out:
# (478032, 361)
# (42888, 361)

# %%
# specify your configurations as a dict
params = {
    
# 核心参数
'task': 'train',# 设置是否是训练任务
'objective': 'binary',# 设置目标  =='application': 'binary',
'boosting_type': 'gbdt',# 设置模型
'num_iterations': 2000,# 最大循环次数
'learning_rate': 0.03,# 学习率
'num_leaves': 35,# 设置一棵树最多有几个叶子，越大越容易过拟合
#'tree_learner':'tree_learner' # 设置并行学习
'num_threads':7,# 指定多少个线程
#'device':'cpu',# 指定设备GPU／cpu

# 学习控制参数
'max_depth':8,# 限制树模型的最大深度，用于减少过拟合，<0表示没有限制
#'min_data_in_leaf':20,# 一个叶子中最少数据个数，用于制止过拟合
#'min_sum_hessian_in_leaf':0.00001,# minimal sum hessian in one leaf,制止过拟合
#'feature_fraction':1.0,# 随机抽取的特征列的占比，用于加快训练和防止过拟合
#'feature_fraction_seed':2,# 随机抽取的特征列的随机产生种子
#'bagging_fraction':1.0,# 随机选择部分数据的占比，用于加快训练和防止过拟合
#'bagging_freq':1,# 每隔k次就进行随机bagging，k=0表示不bagging
#'bagging_seed':3,# bagging的随机产生种子
#'lambda_l1':0,# L1 regularization
#'lambda_l2':10,# L2 regularization
#'min_split_gain':0,# 分裂一次最少要获取多少收益
#'max_cat_threshold':32,# limit the max threshold points in categorical features
#'cat_smooth':10,# 减少类别变量的噪声污染，对于少数据的类别
'cat_l2':4,# 类别分类的L2正则
#'max_cat_to_onehot':4,# 当一个类别总数少于等于4，使用one-vs-other分裂算法
'colsample_bytree':0.8,#在建立树时对特征采样的比例。缺省值为1
'subsample':0.9,#用于训练模型的子样本占整个样本集合的比例。   
# IO参数
#'max_bin':255, #max number of bins that feature values will be bucketed in,小的值可能减少精度，但增加泛化能力
#'min_data_in_bin':3, # min number of data inside one bin, use this to avoid one-data-one-bin (may over-fitting)
#'data_random_seed':1, # random seed for data partition in parallel learning (not include feature parallel)
#'input_model':"" # 训练任务将会继续训练，预测任务直接预测结果
#'is_sparse':True # 离散优化
'verbose': 0,# 是否报出信息，<0 = Fatal, =0 = Error (Warn), >0 = Info

#'bin_construct_sample_cnt':200000 # will give better training result when set this larger, but will increase data loading time
#'num_iteration_predict':-1, # 只用于预测任务，指定用多少训练迭代次数来进行预测，-1表示无限制
#'pred_early_stop':false,# if true will use early-stopping to speed up the prediction. May affect the accuracy
#'use_missing':true,# set to false to disable the special handle of missing value

#目标参数
#'is_unbalance':True,# set this to true if training data are unbalance
    
#指标参数
'eval_metric': 'logloss',#logloss
}

# %% [markdown]
# ## 线下验证

# %%
X_train = train[train.day < 24]
X_val = train[train.day == 24]

# %%
print(X_train.shape)
print(X_val.shape)
# Out:
# (420627, 361)
# (57405, 361)

# %%
train_X = X_train[features].values
train_Y = X_train[target].values.ravel()
val_X = X_val[features].values
val_Y = X_val[target].values.ravel()

# %%
del X_train,X_val
gc.collect()
# Out:
# 26

# %%
# create dataset for lightgbm
lgb_train = lgb.Dataset\
        (data=train_X, label=train_Y,feature_name=features,categorical_feature=cat_features)
lgb_eval = lgb.Dataset\
        (data=val_X, label=val_Y,feature_name=features,categorical_feature=cat_features, reference=lgb_train)

# %%
gbm = lgb.train(params,lgb_train,\
                valid_sets=[lgb_train,lgb_eval],early_stopping_rounds=80,
                categorical_feature=cat_features,verbose_eval=1)#
# Out:
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\lightgbm\basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# [1]	training's binary_logloss: 0.665774	valid_1's binary_logloss: 0.665625
# Training until validation scores don't improve for 80 rounds.
# [2]	training's binary_logloss: 0.639996	valid_1's binary_logloss: 0.639704
# [3]	training's binary_logloss: 0.615679	valid_1's binary_logloss: 0.615254
# [4]	training's binary_logloss: 0.59271	valid_1's binary_logloss: 0.59214
# [5]	training's binary_logloss: 0.570982	valid_1's binary_logloss: 0.570274
# [6]	training's binary_logloss: 0.550403	valid_1's binary_logloss: 0.549561
# [7]	training's binary_logloss: 0.530888	valid_1's binary_logloss: 0.529921
# [8]	training's binary_logloss: 0.512365	valid_1's binary_logloss: 0.511283
# [9]	training's binary_logloss: 0.494763	valid_1's binary_logloss: 0.493584
# [10]	training's binary_logloss: 0.478023	valid_1's binary_logloss: 0.476754
# [11]	training's binary_logloss: 0.462089	valid_1's binary_logloss: 0.4607
# [12]	training's binary_logloss: 0.44691	valid_1's binary_logloss: 0.445417
# [13]	training's binary_logloss: 0.432437	valid_1's binary_logloss: 0.430837
# [14]	training's binary_logloss: 0.418633	valid_1's binary_logloss: 0.416935
# [15]	training's binary_logloss: 0.405453	valid_1's binary_logloss: 0.403645
# [16]	training's binary_logloss: 0.392866	valid_1's binary_logloss: 0.390958
# [17]	training's binary_logloss: 0.380833	valid_1's binary_logloss: 0.378829
# [18]	training's binary_logloss: 0.369327	valid_1's binary_logloss: 0.367231
# [19]	training's binary_logloss: 0.35832	valid_1's binary_logloss: 0.356158
# [20]	training's binary_logloss: 0.347785	valid_1's binary_logloss: 0.345555
# [21]	training's binary_logloss: 0.337695	valid_1's binary_logloss: 0.335373
# [22]	training's binary_logloss: 0.328029	valid_1's binary_logloss: 0.325621
# [23]	training's binary_logloss: 0.318766	valid_1's binary_logloss: 0.316272
# [24]	training's binary_logloss: 0.309885	valid_1's binary_logloss: 0.307302
# [25]	training's binary_logloss: 0.301366	valid_1's binary_logloss: 0.298709
# [26]	training's binary_logloss: 0.293195	valid_1's binary_logloss: 0.290459
# [27]	training's binary_logloss: 0.285352	valid_1's binary_logloss: 0.282549
# [28]	training's binary_logloss: 0.277824	valid_1's binary_logloss: 0.274941
# [29]	training's binary_logloss: 0.270597	valid_1's binary_logloss: 0.267641
# [30]	training's binary_logloss: 0.263655	valid_1's binary_logloss: 0.260628
# [31]	training's binary_logloss: 0.256985	valid_1's binary_logloss: 0.253897
# [32]	training's binary_logloss: 0.250576	valid_1's binary_logloss: 0.247411
# [33]	training's binary_logloss: 0.244416	valid_1's binary_logloss: 0.24118
# [34]	training's binary_logloss: 0.238495	valid_1's binary_logloss: 0.235185
# [35]	training's binary_logloss: 0.232802	valid_1's binary_logloss: 0.229439
# [36]	training's binary_logloss: 0.227327	valid_1's binary_logloss: 0.223895
# [37]	training's binary_logloss: 0.222061	valid_1's binary_logloss: 0.21857
# [38]	training's binary_logloss: 0.216997	valid_1's binary_logloss: 0.213446
# [39]	training's binary_logloss: 0.212125	valid_1's binary_logloss: 0.208526
# [40]	training's binary_logloss: 0.207437	valid_1's binary_logloss: 0.203777
# [41]	training's binary_logloss: 0.202926	valid_1's binary_logloss: 0.199222
# [42]	training's binary_logloss: 0.198584	valid_1's binary_logloss: 0.194838
# [43]	training's binary_logloss: 0.194405	valid_1's binary_logloss: 0.190592
# [44]	training's binary_logloss: 0.190382	valid_1's binary_logloss: 0.186505
# [45]	training's binary_logloss: 0.186507	valid_1's binary_logloss: 0.18257
# [46]	training's binary_logloss: 0.182779	valid_1's binary_logloss: 0.178804
# [47]	training's binary_logloss: 0.179187	valid_1's binary_logloss: 0.175151
# [48]	training's binary_logloss: 0.175728	valid_1's binary_logloss: 0.171628
# [49]	training's binary_logloss: 0.172399	valid_1's binary_logloss: 0.168245
# [50]	training's binary_logloss: 0.169192	valid_1's binary_logloss: 0.164988
# [51]	training's binary_logloss: 0.166106	valid_1's binary_logloss: 0.161848
# [52]	training's binary_logloss: 0.163131	valid_1's binary_logloss: 0.158837
# [53]	training's binary_logloss: 0.160266	valid_1's binary_logloss: 0.155931
# [54]	training's binary_logloss: 0.157509	valid_1's binary_logloss: 0.153125
# [55]	training's binary_logloss: 0.154851	valid_1's binary_logloss: 0.150414
# [56]	training's binary_logloss: 0.152292	valid_1's binary_logloss: 0.147821
# [57]	training's binary_logloss: 0.149825	valid_1's binary_logloss: 0.145311
# [58]	training's binary_logloss: 0.14745	valid_1's binary_logloss: 0.142894
# [59]	training's binary_logloss: 0.145163	valid_1's binary_logloss: 0.140565
# [60]	training's binary_logloss: 0.14296	valid_1's binary_logloss: 0.138318
# [61]	training's binary_logloss: 0.140836	valid_1's binary_logloss: 0.136152
# [62]	training's binary_logloss: 0.138791	valid_1's binary_logloss: 0.134058
# [63]	training's binary_logloss: 0.13682	valid_1's binary_logloss: 0.132048
# [64]	training's binary_logloss: 0.134923	valid_1's binary_logloss: 0.130101
# [65]	training's binary_logloss: 0.133096	valid_1's binary_logloss: 0.128238
# [66]	training's binary_logloss: 0.131336	valid_1's binary_logloss: 0.126431
# [67]	training's binary_logloss: 0.129642	valid_1's binary_logloss: 0.124699
# [68]	training's binary_logloss: 0.128007	valid_1's binary_logloss: 0.123024
# [69]	training's binary_logloss: 0.126435	valid_1's binary_logloss: 0.121418
# [70]	training's binary_logloss: 0.124916	valid_1's binary_logloss: 0.119862
# [71]	training's binary_logloss: 0.123458	valid_1's binary_logloss: 0.118361
# [72]	training's binary_logloss: 0.122052	valid_1's binary_logloss: 0.116926
# [73]	training's binary_logloss: 0.120699	valid_1's binary_logloss: 0.115545
# [74]	training's binary_logloss: 0.119395	valid_1's binary_logloss: 0.114207
# [75]	training's binary_logloss: 0.118138	valid_1's binary_logloss: 0.112922
# [76]	training's binary_logloss: 0.116929	valid_1's binary_logloss: 0.111684
# [77]	training's binary_logloss: 0.115766	valid_1's binary_logloss: 0.110482
# [78]	training's binary_logloss: 0.114647	valid_1's binary_logloss: 0.109341
# [79]	training's binary_logloss: 0.113563	valid_1's binary_logloss: 0.108238
# [80]	training's binary_logloss: 0.112525	valid_1's binary_logloss: 0.107167
# [81]	training's binary_logloss: 0.111526	valid_1's binary_logloss: 0.106135
# [82]	training's binary_logloss: 0.110564	valid_1's binary_logloss: 0.105156
# [83]	training's binary_logloss: 0.109635	valid_1's binary_logloss: 0.10421
# [84]	training's binary_logloss: 0.108741	valid_1's binary_logloss: 0.103291
# [85]	training's binary_logloss: 0.107881	valid_1's binary_logloss: 0.102411
# [86]	training's binary_logloss: 0.107054	valid_1's binary_logloss: 0.101566
# [87]	training's binary_logloss: 0.106258	valid_1's binary_logloss: 0.100755
# [88]	training's binary_logloss: 0.10549	valid_1's binary_logloss: 0.0999631
# [89]	training's binary_logloss: 0.104757	valid_1's binary_logloss: 0.0992049
# [90]	training's binary_logloss: 0.104042	valid_1's binary_logloss: 0.0984812
# [91]	training's binary_logloss: 0.10336	valid_1's binary_logloss: 0.0977832
# [92]	training's binary_logloss: 0.102702	valid_1's binary_logloss: 0.0971069
# [93]	training's binary_logloss: 0.102069	valid_1's binary_logloss: 0.0964597
# [94]	training's binary_logloss: 0.101453	valid_1's binary_logloss: 0.0958382
# [95]	training's binary_logloss: 0.100863	valid_1's binary_logloss: 0.0952423
# [96]	training's binary_logloss: 0.1003	valid_1's binary_logloss: 0.0946682
# [97]	training's binary_logloss: 0.0997517	valid_1's binary_logloss: 0.0941142
# [98]	training's binary_logloss: 0.0992241	valid_1's binary_logloss: 0.0935735
# [99]	training's binary_logloss: 0.0987219	valid_1's binary_logloss: 0.0930657
# [100]	training's binary_logloss: 0.098234	valid_1's binary_logloss: 0.0925637
# [101]	training's binary_logloss: 0.0977628	valid_1's binary_logloss: 0.0920933
# [102]	training's binary_logloss: 0.0973115	valid_1's binary_logloss: 0.091638
# [103]	training's binary_logloss: 0.096876	valid_1's binary_logloss: 0.0911927
# [104]	training's binary_logloss: 0.0964513	valid_1's binary_logloss: 0.0907606
# [105]	training's binary_logloss: 0.0960396	valid_1's binary_logloss: 0.0903624
# [106]	training's binary_logloss: 0.0956549	valid_1's binary_logloss: 0.0899788
# [107]	training's binary_logloss: 0.0952732	valid_1's binary_logloss: 0.0895926
# [108]	training's binary_logloss: 0.0949092	valid_1's binary_logloss: 0.0892248
# [109]	training's binary_logloss: 0.0945556	valid_1's binary_logloss: 0.0888752
# [110]	training's binary_logloss: 0.0942205	valid_1's binary_logloss: 0.0885545
# [111]	training's binary_logloss: 0.0938955	valid_1's binary_logloss: 0.0882302
# [112]	training's binary_logloss: 0.0935864	valid_1's binary_logloss: 0.0879328
# [113]	training's binary_logloss: 0.093283	valid_1's binary_logloss: 0.0876323
# [114]	training's binary_logloss: 0.092993	valid_1's binary_logloss: 0.0873498
# [115]	training's binary_logloss: 0.0927151	valid_1's binary_logloss: 0.0870704
# [116]	training's binary_logloss: 0.0924392	valid_1's binary_logloss: 0.086804
# [117]	training's binary_logloss: 0.0921819	valid_1's binary_logloss: 0.0865622
# [118]	training's binary_logloss: 0.0919253	valid_1's binary_logloss: 0.0863224
# [119]	training's binary_logloss: 0.0916858	valid_1's binary_logloss: 0.0860934
# [120]	training's binary_logloss: 0.0914448	valid_1's binary_logloss: 0.0858649
# [121]	training's binary_logloss: 0.0912161	valid_1's binary_logloss: 0.0856352
# [122]	training's binary_logloss: 0.0909985	valid_1's binary_logloss: 0.0854358
# [123]	training's binary_logloss: 0.0907791	valid_1's binary_logloss: 0.0852333
# [124]	training's binary_logloss: 0.090581	valid_1's binary_logloss: 0.0850497
# [125]	training's binary_logloss: 0.0903829	valid_1's binary_logloss: 0.0848665
# [126]	training's binary_logloss: 0.0901888	valid_1's binary_logloss: 0.0846947
# [127]	training's binary_logloss: 0.0900006	valid_1's binary_logloss: 0.0845216
# [128]	training's binary_logloss: 0.0898124	valid_1's binary_logloss: 0.0843488
# [129]	training's binary_logloss: 0.0896426	valid_1's binary_logloss: 0.084195
# [130]	training's binary_logloss: 0.0894774	valid_1's binary_logloss: 0.0840479
# [131]	training's binary_logloss: 0.0893117	valid_1's binary_logloss: 0.0838948
# [132]	training's binary_logloss: 0.0891453	valid_1's binary_logloss: 0.0837561
# [133]	training's binary_logloss: 0.0889922	valid_1's binary_logloss: 0.0836174
# [134]	training's binary_logloss: 0.0888392	valid_1's binary_logloss: 0.0834904
# [135]	training's binary_logloss: 0.0886899	valid_1's binary_logloss: 0.0833711
# [136]	training's binary_logloss: 0.088548	valid_1's binary_logloss: 0.0832523
# [137]	training's binary_logloss: 0.0884104	valid_1's binary_logloss: 0.0831426
# [138]	training's binary_logloss: 0.088276	valid_1's binary_logloss: 0.0830291
# [139]	training's binary_logloss: 0.0881479	valid_1's binary_logloss: 0.0829228
# [140]	training's binary_logloss: 0.0880182	valid_1's binary_logloss: 0.0828219
# [141]	training's binary_logloss: 0.0878954	valid_1's binary_logloss: 0.08272
# [142]	training's binary_logloss: 0.0877771	valid_1's binary_logloss: 0.0826213
# [143]	training's binary_logloss: 0.0876599	valid_1's binary_logloss: 0.0825332
# [144]	training's binary_logloss: 0.0875418	valid_1's binary_logloss: 0.0824474
# [145]	training's binary_logloss: 0.0874258	valid_1's binary_logloss: 0.0823563
# [146]	training's binary_logloss: 0.0873195	valid_1's binary_logloss: 0.0822738
# [147]	training's binary_logloss: 0.0872149	valid_1's binary_logloss: 0.0822033
# [148]	training's binary_logloss: 0.0871049	valid_1's binary_logloss: 0.0821283
# [149]	training's binary_logloss: 0.0870073	valid_1's binary_logloss: 0.0820543
# [150]	training's binary_logloss: 0.0869075	valid_1's binary_logloss: 0.0819828
# [151]	training's binary_logloss: 0.0868117	valid_1's binary_logloss: 0.0819141
# [152]	training's binary_logloss: 0.0867128	valid_1's binary_logloss: 0.0818439
# [153]	training's binary_logloss: 0.0866194	valid_1's binary_logloss: 0.0817879
# [154]	training's binary_logloss: 0.0865182	valid_1's binary_logloss: 0.0817317
# [155]	training's binary_logloss: 0.0864287	valid_1's binary_logloss: 0.0816638
# [156]	training's binary_logloss: 0.0863363	valid_1's binary_logloss: 0.0816119
# [157]	training's binary_logloss: 0.0862517	valid_1's binary_logloss: 0.0815641
# [158]	training's binary_logloss: 0.086167	valid_1's binary_logloss: 0.0815135
# [159]	training's binary_logloss: 0.0860783	valid_1's binary_logloss: 0.0814805
# [160]	training's binary_logloss: 0.0859954	valid_1's binary_logloss: 0.0814359
# [161]	training's binary_logloss: 0.0859082	valid_1's binary_logloss: 0.0813887
# [162]	training's binary_logloss: 0.0858257	valid_1's binary_logloss: 0.0813378
# [163]	training's binary_logloss: 0.0857497	valid_1's binary_logloss: 0.0812973
# [164]	training's binary_logloss: 0.0856703	valid_1's binary_logloss: 0.0812527
# [165]	training's binary_logloss: 0.0855836	valid_1's binary_logloss: 0.0812187
# [166]	training's binary_logloss: 0.0855125	valid_1's binary_logloss: 0.0811709
# [167]	training's binary_logloss: 0.0854324	valid_1's binary_logloss: 0.0811284
# [168]	training's binary_logloss: 0.0853628	valid_1's binary_logloss: 0.0810859
# [169]	training's binary_logloss: 0.0852897	valid_1's binary_logloss: 0.0810521
# [170]	training's binary_logloss: 0.0852181	valid_1's binary_logloss: 0.0810167
# [171]	training's binary_logloss: 0.085154	valid_1's binary_logloss: 0.0809761
# [172]	training's binary_logloss: 0.0850883	valid_1's binary_logloss: 0.080948
# [173]	training's binary_logloss: 0.0850139	valid_1's binary_logloss: 0.0809159
# [174]	training's binary_logloss: 0.0849465	valid_1's binary_logloss: 0.0808918
# [175]	training's binary_logloss: 0.0848789	valid_1's binary_logloss: 0.0808599
# [176]	training's binary_logloss: 0.0848091	valid_1's binary_logloss: 0.0808177
# [177]	training's binary_logloss: 0.0847441	valid_1's binary_logloss: 0.0807801
# [178]	training's binary_logloss: 0.0846786	valid_1's binary_logloss: 0.0807448
# [179]	training's binary_logloss: 0.0846104	valid_1's binary_logloss: 0.0807167
# [180]	training's binary_logloss: 0.0845528	valid_1's binary_logloss: 0.0806913
# [181]	training's binary_logloss: 0.0844935	valid_1's binary_logloss: 0.0806654
# [182]	training's binary_logloss: 0.0844346	valid_1's binary_logloss: 0.0806294
# [183]	training's binary_logloss: 0.0843778	valid_1's binary_logloss: 0.080614
# [184]	training's binary_logloss: 0.0843086	valid_1's binary_logloss: 0.0805957
# [185]	training's binary_logloss: 0.0842468	valid_1's binary_logloss: 0.0805824
# [186]	training's binary_logloss: 0.0841865	valid_1's binary_logloss: 0.0805603
# [187]	training's binary_logloss: 0.0841289	valid_1's binary_logloss: 0.0805306
# [188]	training's binary_logloss: 0.084078	valid_1's binary_logloss: 0.0805042
# [189]	training's binary_logloss: 0.0840265	valid_1's binary_logloss: 0.0804897
# [190]	training's binary_logloss: 0.0839756	valid_1's binary_logloss: 0.0804667
# [191]	training's binary_logloss: 0.0839205	valid_1's binary_logloss: 0.08043
# [192]	training's binary_logloss: 0.0838643	valid_1's binary_logloss: 0.0804063
# [193]	training's binary_logloss: 0.08381	valid_1's binary_logloss: 0.0803976
# [194]	training's binary_logloss: 0.0837585	valid_1's binary_logloss: 0.0803737
# [195]	training's binary_logloss: 0.0837034	valid_1's binary_logloss: 0.0803563
# [196]	training's binary_logloss: 0.0836523	valid_1's binary_logloss: 0.0803428
# [197]	training's binary_logloss: 0.0835951	valid_1's binary_logloss: 0.0803215
# [198]	training's binary_logloss: 0.0835361	valid_1's binary_logloss: 0.080294
# [199]	training's binary_logloss: 0.0834784	valid_1's binary_logloss: 0.080278
# [200]	training's binary_logloss: 0.0834259	valid_1's binary_logloss: 0.0802574
# [201]	training's binary_logloss: 0.0833678	valid_1's binary_logloss: 0.080247
# [202]	training's binary_logloss: 0.0833148	valid_1's binary_logloss: 0.080231
# [203]	training's binary_logloss: 0.0832552	valid_1's binary_logloss: 0.0802208
# [204]	training's binary_logloss: 0.0831996	valid_1's binary_logloss: 0.0802004
# [205]	training's binary_logloss: 0.0831539	valid_1's binary_logloss: 0.0801845
# [206]	training's binary_logloss: 0.0830998	valid_1's binary_logloss: 0.0801724
# [207]	training's binary_logloss: 0.0830466	valid_1's binary_logloss: 0.0801546
# [208]	training's binary_logloss: 0.0829916	valid_1's binary_logloss: 0.0801339
# [209]	training's binary_logloss: 0.0829416	valid_1's binary_logloss: 0.0801279
# [210]	training's binary_logloss: 0.0828833	valid_1's binary_logloss: 0.0801264
# [211]	training's binary_logloss: 0.0828346	valid_1's binary_logloss: 0.080116
# [212]	training's binary_logloss: 0.082787	valid_1's binary_logloss: 0.0801121
# [213]	training's binary_logloss: 0.0827341	valid_1's binary_logloss: 0.080106
# [214]	training's binary_logloss: 0.0826842	valid_1's binary_logloss: 0.0800879
# [215]	training's binary_logloss: 0.0826396	valid_1's binary_logloss: 0.0800798
# [216]	training's binary_logloss: 0.0825901	valid_1's binary_logloss: 0.0800744
# [217]	training's binary_logloss: 0.0825427	valid_1's binary_logloss: 0.080063
# [218]	training's binary_logloss: 0.0824928	valid_1's binary_logloss: 0.0800465
# [219]	training's binary_logloss: 0.0824493	valid_1's binary_logloss: 0.0800348
# [220]	training's binary_logloss: 0.0824002	valid_1's binary_logloss: 0.0800215
# [221]	training's binary_logloss: 0.0823542	valid_1's binary_logloss: 0.080021
# [222]	training's binary_logloss: 0.0823132	valid_1's binary_logloss: 0.0800095
# [223]	training's binary_logloss: 0.0822678	valid_1's binary_logloss: 0.0800054
# [224]	training's binary_logloss: 0.0822263	valid_1's binary_logloss: 0.0799949
# [225]	training's binary_logloss: 0.0821797	valid_1's binary_logloss: 0.0799839
# [226]	training's binary_logloss: 0.0821377	valid_1's binary_logloss: 0.0799787
# [227]	training's binary_logloss: 0.082097	valid_1's binary_logloss: 0.0799674
# [228]	training's binary_logloss: 0.0820503	valid_1's binary_logloss: 0.0799583
# [229]	training's binary_logloss: 0.0820047	valid_1's binary_logloss: 0.079952
# [230]	training's binary_logloss: 0.0819632	valid_1's binary_logloss: 0.0799474
# [231]	training's binary_logloss: 0.0818992	valid_1's binary_logloss: 0.0799442
# [232]	training's binary_logloss: 0.0818553	valid_1's binary_logloss: 0.07993
# [233]	training's binary_logloss: 0.0818127	valid_1's binary_logloss: 0.0799207
# [234]	training's binary_logloss: 0.081772	valid_1's binary_logloss: 0.0799134
# [235]	training's binary_logloss: 0.081719	valid_1's binary_logloss: 0.0799097
# [236]	training's binary_logloss: 0.0816783	valid_1's binary_logloss: 0.0799046
# [237]	training's binary_logloss: 0.0816375	valid_1's binary_logloss: 0.0798968
# [238]	training's binary_logloss: 0.081589	valid_1's binary_logloss: 0.0798891
# [239]	training's binary_logloss: 0.0815502	valid_1's binary_logloss: 0.0798907
# [240]	training's binary_logloss: 0.081508	valid_1's binary_logloss: 0.0798835
# [241]	training's binary_logloss: 0.0814657	valid_1's binary_logloss: 0.0798744
# [242]	training's binary_logloss: 0.0814248	valid_1's binary_logloss: 0.0798719
# [243]	training's binary_logloss: 0.0813837	valid_1's binary_logloss: 0.0798583
# [244]	training's binary_logloss: 0.0813469	valid_1's binary_logloss: 0.0798504
# [245]	training's binary_logloss: 0.0813007	valid_1's binary_logloss: 0.0798541
# [246]	training's binary_logloss: 0.0812551	valid_1's binary_logloss: 0.0798481
# [247]	training's binary_logloss: 0.081213	valid_1's binary_logloss: 0.0798456
# [248]	training's binary_logloss: 0.0811624	valid_1's binary_logloss: 0.0798412
# [249]	training's binary_logloss: 0.0811214	valid_1's binary_logloss: 0.0798378
# [250]	training's binary_logloss: 0.0810758	valid_1's binary_logloss: 0.0798312
# [251]	training's binary_logloss: 0.0810395	valid_1's binary_logloss: 0.0798235
# [252]	training's binary_logloss: 0.081001	valid_1's binary_logloss: 0.0798158
# [253]	training's binary_logloss: 0.0809554	valid_1's binary_logloss: 0.0798037
# [254]	training's binary_logloss: 0.080918	valid_1's binary_logloss: 0.079798
# [255]	training's binary_logloss: 0.0808806	valid_1's binary_logloss: 0.0797976
# [256]	training's binary_logloss: 0.0808417	valid_1's binary_logloss: 0.0797925
# [257]	training's binary_logloss: 0.0807893	valid_1's binary_logloss: 0.0797954
# [258]	training's binary_logloss: 0.0807463	valid_1's binary_logloss: 0.0797944
# [259]	training's binary_logloss: 0.0807031	valid_1's binary_logloss: 0.079791
# [260]	training's binary_logloss: 0.0806636	valid_1's binary_logloss: 0.0797851
# [261]	training's binary_logloss: 0.0806208	valid_1's binary_logloss: 0.0797838
# [262]	training's binary_logloss: 0.0805842	valid_1's binary_logloss: 0.0797807
# [263]	training's binary_logloss: 0.0805373	valid_1's binary_logloss: 0.0797841
# [264]	training's binary_logloss: 0.080498	valid_1's binary_logloss: 0.0797842
# [265]	training's binary_logloss: 0.0804585	valid_1's binary_logloss: 0.0797757
# [266]	training's binary_logloss: 0.0804181	valid_1's binary_logloss: 0.0797767
# [267]	training's binary_logloss: 0.0803814	valid_1's binary_logloss: 0.0797789
# [268]	training's binary_logloss: 0.0803417	valid_1's binary_logloss: 0.0797761
# [269]	training's binary_logloss: 0.0802933	valid_1's binary_logloss: 0.0797712
# [270]	training's binary_logloss: 0.0802568	valid_1's binary_logloss: 0.079763
# [271]	training's binary_logloss: 0.0802192	valid_1's binary_logloss: 0.0797607
# [272]	training's binary_logloss: 0.0801819	valid_1's binary_logloss: 0.0797612
# [273]	training's binary_logloss: 0.080146	valid_1's binary_logloss: 0.0797685
# [274]	training's binary_logloss: 0.0801112	valid_1's binary_logloss: 0.0797712
# [275]	training's binary_logloss: 0.0800679	valid_1's binary_logloss: 0.0797693
# [276]	training's binary_logloss: 0.0800273	valid_1's binary_logloss: 0.0797724
# [277]	training's binary_logloss: 0.0799823	valid_1's binary_logloss: 0.0797722
# [278]	training's binary_logloss: 0.0799414	valid_1's binary_logloss: 0.0797746
# [279]	training's binary_logloss: 0.0799044	valid_1's binary_logloss: 0.0797666
# [280]	training's binary_logloss: 0.0798717	valid_1's binary_logloss: 0.0797662
# [281]	training's binary_logloss: 0.0798355	valid_1's binary_logloss: 0.0797725
# [282]	training's binary_logloss: 0.0798021	valid_1's binary_logloss: 0.0797622
# [283]	training's binary_logloss: 0.0797673	valid_1's binary_logloss: 0.0797667
# [284]	training's binary_logloss: 0.0797352	valid_1's binary_logloss: 0.0797646
# [285]	training's binary_logloss: 0.0796988	valid_1's binary_logloss: 0.0797644
# [286]	training's binary_logloss: 0.0796557	valid_1's binary_logloss: 0.0797595
# [287]	training's binary_logloss: 0.0796189	valid_1's binary_logloss: 0.0797499
# [288]	training's binary_logloss: 0.0795834	valid_1's binary_logloss: 0.0797511
# [289]	training's binary_logloss: 0.0795526	valid_1's binary_logloss: 0.0797489
# [290]	training's binary_logloss: 0.0795129	valid_1's binary_logloss: 0.0797496
# [291]	training's binary_logloss: 0.0794827	valid_1's binary_logloss: 0.0797403
# [292]	training's binary_logloss: 0.079429	valid_1's binary_logloss: 0.0797444
# [293]	training's binary_logloss: 0.0793972	valid_1's binary_logloss: 0.0797442
# [294]	training's binary_logloss: 0.0793588	valid_1's binary_logloss: 0.0797342
# [295]	training's binary_logloss: 0.07932	valid_1's binary_logloss: 0.0797238
# [296]	training's binary_logloss: 0.0792891	valid_1's binary_logloss: 0.0797197
# [297]	training's binary_logloss: 0.0792489	valid_1's binary_logloss: 0.079714
# [298]	training's binary_logloss: 0.07922	valid_1's binary_logloss: 0.0797127
# [299]	training's binary_logloss: 0.0791906	valid_1's binary_logloss: 0.0797079
# [300]	training's binary_logloss: 0.0791513	valid_1's binary_logloss: 0.0797137
# [301]	training's binary_logloss: 0.0791145	valid_1's binary_logloss: 0.0797119
# [302]	training's binary_logloss: 0.0790816	valid_1's binary_logloss: 0.0797129
# [303]	training's binary_logloss: 0.0790477	valid_1's binary_logloss: 0.0797066
# [304]	training's binary_logloss: 0.0790139	valid_1's binary_logloss: 0.079702
# [305]	training's binary_logloss: 0.0789794	valid_1's binary_logloss: 0.0797027
# [306]	training's binary_logloss: 0.0789493	valid_1's binary_logloss: 0.0797001
# [307]	training's binary_logloss: 0.0789144	valid_1's binary_logloss: 0.0796931
# [308]	training's binary_logloss: 0.0788817	valid_1's binary_logloss: 0.0796908
# [309]	training's binary_logloss: 0.0788495	valid_1's binary_logloss: 0.0796828
# [310]	training's binary_logloss: 0.0788165	valid_1's binary_logloss: 0.0796778
# [311]	training's binary_logloss: 0.0787778	valid_1's binary_logloss: 0.0796813
# [312]	training's binary_logloss: 0.078737	valid_1's binary_logloss: 0.0796881
# [313]	training's binary_logloss: 0.078688	valid_1's binary_logloss: 0.0796824
# [314]	training's binary_logloss: 0.0786513	valid_1's binary_logloss: 0.0796788
# [315]	training's binary_logloss: 0.0786237	valid_1's binary_logloss: 0.0796788
# [316]	training's binary_logloss: 0.0785891	valid_1's binary_logloss: 0.0796789
# [317]	training's binary_logloss: 0.0785488	valid_1's binary_logloss: 0.0796797
# [318]	training's binary_logloss: 0.0785137	valid_1's binary_logloss: 0.0796783
# [319]	training's binary_logloss: 0.0784875	valid_1's binary_logloss: 0.0796798
# [320]	training's binary_logloss: 0.0784476	valid_1's binary_logloss: 0.0796779
# [321]	training's binary_logloss: 0.078419	valid_1's binary_logloss: 0.0796815
# [322]	training's binary_logloss: 0.0783818	valid_1's binary_logloss: 0.0796798
# [323]	training's binary_logloss: 0.0783439	valid_1's binary_logloss: 0.0796846
# [324]	training's binary_logloss: 0.0783077	valid_1's binary_logloss: 0.0796828
# [325]	training's binary_logloss: 0.0782662	valid_1's binary_logloss: 0.0796894
# [326]	training's binary_logloss: 0.0782326	valid_1's binary_logloss: 0.07969
# [327]	training's binary_logloss: 0.0782034	valid_1's binary_logloss: 0.079695
# [328]	training's binary_logloss: 0.078175	valid_1's binary_logloss: 0.0797004
# [329]	training's binary_logloss: 0.0781447	valid_1's binary_logloss: 0.0797033
# [330]	training's binary_logloss: 0.0781092	valid_1's binary_logloss: 0.0796968
# [331]	training's binary_logloss: 0.078077	valid_1's binary_logloss: 0.0796902
# [332]	training's binary_logloss: 0.0780421	valid_1's binary_logloss: 0.0796897
# [333]	training's binary_logloss: 0.0780137	valid_1's binary_logloss: 0.0796877
# [334]	training's binary_logloss: 0.0779747	valid_1's binary_logloss: 0.0796887
# [335]	training's binary_logloss: 0.0779383	valid_1's binary_logloss: 0.0796847
# [336]	training's binary_logloss: 0.0779029	valid_1's binary_logloss: 0.0796863
# [337]	training's binary_logloss: 0.0778768	valid_1's binary_logloss: 0.0796859
# [338]	training's binary_logloss: 0.077845	valid_1's binary_logloss: 0.0796839
# [339]	training's binary_logloss: 0.077814	valid_1's binary_logloss: 0.0796823
# [340]	training's binary_logloss: 0.0777758	valid_1's binary_logloss: 0.0796863
# [341]	training's binary_logloss: 0.0777448	valid_1's binary_logloss: 0.0796922
# [342]	training's binary_logloss: 0.0777141	valid_1's binary_logloss: 0.0796938
# [343]	training's binary_logloss: 0.0776832	valid_1's binary_logloss: 0.0796959
# [344]	training's binary_logloss: 0.0776505	valid_1's binary_logloss: 0.0796969
# [345]	training's binary_logloss: 0.0776141	valid_1's binary_logloss: 0.0796945
# [346]	training's binary_logloss: 0.0775806	valid_1's binary_logloss: 0.0796867
# [347]	training's binary_logloss: 0.0775495	valid_1's binary_logloss: 0.0796783
# [348]	training's binary_logloss: 0.0775153	valid_1's binary_logloss: 0.0796796
# [349]	training's binary_logloss: 0.0774851	valid_1's binary_logloss: 0.0796723
# [350]	training's binary_logloss: 0.0774576	valid_1's binary_logloss: 0.0796735
# [351]	training's binary_logloss: 0.077428	valid_1's binary_logloss: 0.0796712
# [352]	training's binary_logloss: 0.0774018	valid_1's binary_logloss: 0.0796741
# [353]	training's binary_logloss: 0.0773701	valid_1's binary_logloss: 0.0796746
# [354]	training's binary_logloss: 0.0773422	valid_1's binary_logloss: 0.0796783
# [355]	training's binary_logloss: 0.0773044	valid_1's binary_logloss: 0.0796796
# [356]	training's binary_logloss: 0.0772863	valid_1's binary_logloss: 0.0796777
# [357]	training's binary_logloss: 0.077251	valid_1's binary_logloss: 0.0796678
# [358]	training's binary_logloss: 0.0772223	valid_1's binary_logloss: 0.0796659
# [359]	training's binary_logloss: 0.0771983	valid_1's binary_logloss: 0.0796667
# [360]	training's binary_logloss: 0.0771635	valid_1's binary_logloss: 0.0796677
# [361]	training's binary_logloss: 0.077135	valid_1's binary_logloss: 0.0796734
# [362]	training's binary_logloss: 0.0771041	valid_1's binary_logloss: 0.079675
# [363]	training's binary_logloss: 0.0770749	valid_1's binary_logloss: 0.079673
# [364]	training's binary_logloss: 0.0770328	valid_1's binary_logloss: 0.079675
# [365]	training's binary_logloss: 0.0770114	valid_1's binary_logloss: 0.079674
# [366]	training's binary_logloss: 0.0769848	valid_1's binary_logloss: 0.0796751
# [367]	training's binary_logloss: 0.0769499	valid_1's binary_logloss: 0.0796719
# [368]	training's binary_logloss: 0.0769258	valid_1's binary_logloss: 0.0796711
# [369]	training's binary_logloss: 0.0769112	valid_1's binary_logloss: 0.0796725
# [370]	training's binary_logloss: 0.0768833	valid_1's binary_logloss: 0.0796709
# [371]	training's binary_logloss: 0.0768544	valid_1's binary_logloss: 0.07967
# [372]	training's binary_logloss: 0.0768281	valid_1's binary_logloss: 0.0796683
# [373]	training's binary_logloss: 0.0767812	valid_1's binary_logloss: 0.0796728
# [374]	training's binary_logloss: 0.0767477	valid_1's binary_logloss: 0.0796689
# [375]	training's binary_logloss: 0.0767188	valid_1's binary_logloss: 0.0796756
# [376]	training's binary_logloss: 0.0766807	valid_1's binary_logloss: 0.0796613
# [377]	training's binary_logloss: 0.0766516	valid_1's binary_logloss: 0.0796627
# [378]	training's binary_logloss: 0.0766219	valid_1's binary_logloss: 0.0796564
# [379]	training's binary_logloss: 0.0765993	valid_1's binary_logloss: 0.0796591
# [380]	training's binary_logloss: 0.0765575	valid_1's binary_logloss: 0.0796506
# [381]	training's binary_logloss: 0.076525	valid_1's binary_logloss: 0.0796464
# [382]	training's binary_logloss: 0.0764983	valid_1's binary_logloss: 0.0796465
# [383]	training's binary_logloss: 0.0764782	valid_1's binary_logloss: 0.0796482
# [384]	training's binary_logloss: 0.0764519	valid_1's binary_logloss: 0.0796443
# [385]	training's binary_logloss: 0.0764231	valid_1's binary_logloss: 0.0796464
# [386]	training's binary_logloss: 0.0763912	valid_1's binary_logloss: 0.0796517
# [387]	training's binary_logloss: 0.0763574	valid_1's binary_logloss: 0.0796532
# [388]	training's binary_logloss: 0.0763317	valid_1's binary_logloss: 0.0796538
# [389]	training's binary_logloss: 0.0762954	valid_1's binary_logloss: 0.0796541
# [390]	training's binary_logloss: 0.0762592	valid_1's binary_logloss: 0.0796569
# [391]	training's binary_logloss: 0.0762292	valid_1's binary_logloss: 0.0796598
# [392]	training's binary_logloss: 0.0761976	valid_1's binary_logloss: 0.0796625
# [393]	training's binary_logloss: 0.0761749	valid_1's binary_logloss: 0.079658
# [394]	training's binary_logloss: 0.0761456	valid_1's binary_logloss: 0.0796555
# [395]	training's binary_logloss: 0.0761218	valid_1's binary_logloss: 0.0796526
# [396]	training's binary_logloss: 0.0760977	valid_1's binary_logloss: 0.0796489
# [397]	training's binary_logloss: 0.0760696	valid_1's binary_logloss: 0.0796527
# [398]	training's binary_logloss: 0.0760431	valid_1's binary_logloss: 0.0796542
# [399]	training's binary_logloss: 0.0760148	valid_1's binary_logloss: 0.0796556
# [400]	training's binary_logloss: 0.0759866	valid_1's binary_logloss: 0.079658
# [401]	training's binary_logloss: 0.0759651	valid_1's binary_logloss: 0.0796566
# [402]	training's binary_logloss: 0.0759425	valid_1's binary_logloss: 0.0796603
# [403]	training's binary_logloss: 0.0759242	valid_1's binary_logloss: 0.0796584
# [404]	training's binary_logloss: 0.0758886	valid_1's binary_logloss: 0.0796546
# [405]	training's binary_logloss: 0.0758603	valid_1's binary_logloss: 0.0796595
# [406]	training's binary_logloss: 0.0758417	valid_1's binary_logloss: 0.07966
# [407]	training's binary_logloss: 0.0758162	valid_1's binary_logloss: 0.0796569
# [408]	training's binary_logloss: 0.0757776	valid_1's binary_logloss: 0.0796582
# [409]	training's binary_logloss: 0.0757574	valid_1's binary_logloss: 0.0796583
# [410]	training's binary_logloss: 0.0757294	valid_1's binary_logloss: 0.0796549
# [411]	training's binary_logloss: 0.0757022	valid_1's binary_logloss: 0.0796528
# [412]	training's binary_logloss: 0.0756871	valid_1's binary_logloss: 0.079654
# [413]	training's binary_logloss: 0.0756548	valid_1's binary_logloss: 0.0796589
# [414]	training's binary_logloss: 0.0756241	valid_1's binary_logloss: 0.07966
# [415]	training's binary_logloss: 0.0756002	valid_1's binary_logloss: 0.0796662
# [416]	training's binary_logloss: 0.0755773	valid_1's binary_logloss: 0.0796675
# [417]	training's binary_logloss: 0.0755484	valid_1's binary_logloss: 0.079668
# [418]	training's binary_logloss: 0.0755274	valid_1's binary_logloss: 0.0796701
# [419]	training's binary_logloss: 0.0755058	valid_1's binary_logloss: 0.0796692
# [420]	training's binary_logloss: 0.0754762	valid_1's binary_logloss: 0.0796672
# [421]	training's binary_logloss: 0.0754507	valid_1's binary_logloss: 0.0796636
# [422]	training's binary_logloss: 0.0754195	valid_1's binary_logloss: 0.0796613
# [423]	training's binary_logloss: 0.0753964	valid_1's binary_logloss: 0.079665
# [424]	training's binary_logloss: 0.0753793	valid_1's binary_logloss: 0.0796659
# [425]	training's binary_logloss: 0.0753535	valid_1's binary_logloss: 0.0796646
# [426]	training's binary_logloss: 0.0753181	valid_1's binary_logloss: 0.0796699
# [427]	training's binary_logloss: 0.0752881	valid_1's binary_logloss: 0.0796705
# [428]	training's binary_logloss: 0.0752557	valid_1's binary_logloss: 0.0796732
# [429]	training's binary_logloss: 0.0752257	valid_1's binary_logloss: 0.0796751
# [430]	training's binary_logloss: 0.075204	valid_1's binary_logloss: 0.0796763
# [431]	training's binary_logloss: 0.0751767	valid_1's binary_logloss: 0.0796678
# [432]	training's binary_logloss: 0.0751453	valid_1's binary_logloss: 0.0796703
# [433]	training's binary_logloss: 0.0751156	valid_1's binary_logloss: 0.079668
# [434]	training's binary_logloss: 0.0750858	valid_1's binary_logloss: 0.0796681
# [435]	training's binary_logloss: 0.0750534	valid_1's binary_logloss: 0.079664
# [436]	training's binary_logloss: 0.0750169	valid_1's binary_logloss: 0.0796655
# [437]	training's binary_logloss: 0.0749981	valid_1's binary_logloss: 0.0796642
# [438]	training's binary_logloss: 0.0749726	valid_1's binary_logloss: 0.0796617
# [439]	training's binary_logloss: 0.0749485	valid_1's binary_logloss: 0.0796631
# [440]	training's binary_logloss: 0.0749177	valid_1's binary_logloss: 0.0796626
# [441]	training's binary_logloss: 0.0748918	valid_1's binary_logloss: 0.0796648
# [442]	training's binary_logloss: 0.0748559	valid_1's binary_logloss: 0.079666
# [443]	training's binary_logloss: 0.0748255	valid_1's binary_logloss: 0.0796627
# [444]	training's binary_logloss: 0.0748023	valid_1's binary_logloss: 0.0796583
# [445]	training's binary_logloss: 0.0747723	valid_1's binary_logloss: 0.0796571
# [446]	training's binary_logloss: 0.0747496	valid_1's binary_logloss: 0.0796607
# [447]	training's binary_logloss: 0.074718	valid_1's binary_logloss: 0.0796646
# [448]	training's binary_logloss: 0.0746944	valid_1's binary_logloss: 0.0796652
# [449]	training's binary_logloss: 0.0746576	valid_1's binary_logloss: 0.0796659
# [450]	training's binary_logloss: 0.0746356	valid_1's binary_logloss: 0.0796703
# [451]	training's binary_logloss: 0.0746084	valid_1's binary_logloss: 0.0796636
# [452]	training's binary_logloss: 0.0745898	valid_1's binary_logloss: 0.0796632
# [453]	training's binary_logloss: 0.0745642	valid_1's binary_logloss: 0.0796632
# [454]	training's binary_logloss: 0.07454	valid_1's binary_logloss: 0.0796603
# [455]	training's binary_logloss: 0.0745103	valid_1's binary_logloss: 0.0796524
# [456]	training's binary_logloss: 0.0744814	valid_1's binary_logloss: 0.079653
# [457]	training's binary_logloss: 0.0744582	valid_1's binary_logloss: 0.0796565
# [458]	training's binary_logloss: 0.074427	valid_1's binary_logloss: 0.0796549
# [459]	training's binary_logloss: 0.0744044	valid_1's binary_logloss: 0.0796554
# [460]	training's binary_logloss: 0.0743669	valid_1's binary_logloss: 0.0796584
# [461]	training's binary_logloss: 0.0743456	valid_1's binary_logloss: 0.0796575
# [462]	training's binary_logloss: 0.074325	valid_1's binary_logloss: 0.0796571
# [463]	training's binary_logloss: 0.0742992	valid_1's binary_logloss: 0.0796614
# [464]	training's binary_logloss: 0.0742758	valid_1's binary_logloss: 0.0796552
# Early stopping, best iteration is:
# [384]	training's binary_logloss: 0.0764519	valid_1's binary_logloss: 0.0796443

# %%
fig,ax = plt.subplots(figsize=(30,30))
lgb.plot_importance(gbm,
                  height=1,
                  ax=ax,
                  max_num_features=128)
plt.show()

# %%
del gbm
del lgb_train,lgb_eval
del train_X,train_Y,val_X,val_Y

# %% [markdown]
# ## 线上提交

# %%
train_X = train[features].values
train_Y = train[target].values.ravel()
test_X = test[features].values

# %%
del train
gc.collect()
# Out:
# 39

# %%
lgb_train = lgb.Dataset\
        (data=train_X, label=train_Y,feature_name=features,categorical_feature = cat_features)

# %%
del train_X,train_Y
gc.collect()
# Out:
# 0

# %%
gbm = lgb.train(params,lgb_train,\
                valid_sets=[lgb_train],num_boost_round=400,
                categorical_feature=cat_features,verbose_eval=5)
# Out:
# [5]	training's binary_logloss: 0.570854
# [10]	training's binary_logloss: 0.477793
# [15]	training's binary_logloss: 0.40514
# [20]	training's binary_logloss: 0.3474
# [25]	training's binary_logloss: 0.300922
# [30]	training's binary_logloss: 0.263158
# [35]	training's binary_logloss: 0.232262
# [40]	training's binary_logloss: 0.206857
# [45]	training's binary_logloss: 0.18589
# [50]	training's binary_logloss: 0.168543
# [55]	training's binary_logloss: 0.154173
# [60]	training's binary_logloss: 0.142256
# [65]	training's binary_logloss: 0.132374
# [70]	training's binary_logloss: 0.124179
# [75]	training's binary_logloss: 0.11739
# [80]	training's binary_logloss: 0.111768
# [85]	training's binary_logloss: 0.107116
# [90]	training's binary_logloss: 0.103273
# [95]	training's binary_logloss: 0.100091
# [100]	training's binary_logloss: 0.0974588
# [105]	training's binary_logloss: 0.0952834
# [110]	training's binary_logloss: 0.0934857
# [115]	training's binary_logloss: 0.0919881
# [120]	training's binary_logloss: 0.0907411
# [125]	training's binary_logloss: 0.0897045
# [130]	training's binary_logloss: 0.0888257
# [135]	training's binary_logloss: 0.0880779
# [140]	training's binary_logloss: 0.0874296
# [145]	training's binary_logloss: 0.0868662
# [150]	training's binary_logloss: 0.0863564
# [155]	training's binary_logloss: 0.0859007
# [160]	training's binary_logloss: 0.0854944
# [165]	training's binary_logloss: 0.0851348
# [170]	training's binary_logloss: 0.0847829
# [175]	training's binary_logloss: 0.0844665
# [180]	training's binary_logloss: 0.084172
# [185]	training's binary_logloss: 0.0838818
# [190]	training's binary_logloss: 0.0836156
# [195]	training's binary_logloss: 0.0833652
# [200]	training's binary_logloss: 0.08312
# [205]	training's binary_logloss: 0.0828704
# [210]	training's binary_logloss: 0.0826388
# [215]	training's binary_logloss: 0.0824111
# [220]	training's binary_logloss: 0.0822027
# [225]	training's binary_logloss: 0.0819855
# [230]	training's binary_logloss: 0.0817669
# [235]	training's binary_logloss: 0.0815541
# [240]	training's binary_logloss: 0.0813542
# [245]	training's binary_logloss: 0.0811488
# [250]	training's binary_logloss: 0.0809627
# [255]	training's binary_logloss: 0.0807738
# [260]	training's binary_logloss: 0.0805707
# [265]	training's binary_logloss: 0.0803902
# [270]	training's binary_logloss: 0.0802036
# [275]	training's binary_logloss: 0.0800086
# [280]	training's binary_logloss: 0.0798072
# [285]	training's binary_logloss: 0.0796182
# [290]	training's binary_logloss: 0.0794395
# [295]	training's binary_logloss: 0.0792652
# [300]	training's binary_logloss: 0.0790954
# [305]	training's binary_logloss: 0.0789313
# [310]	training's binary_logloss: 0.0787658
# [315]	training's binary_logloss: 0.0786043
# [320]	training's binary_logloss: 0.0784216
# [325]	training's binary_logloss: 0.0782659
# [330]	training's binary_logloss: 0.0780995
# [335]	training's binary_logloss: 0.0779418
# [340]	training's binary_logloss: 0.0777862
# [345]	training's binary_logloss: 0.0776332
# [350]	training's binary_logloss: 0.0774838
# [355]	training's binary_logloss: 0.0773486
# [360]	training's binary_logloss: 0.0772011
# [365]	training's binary_logloss: 0.0770588
# [370]	training's binary_logloss: 0.0769013
# [375]	training's binary_logloss: 0.0767597
# [380]	training's binary_logloss: 0.0766204

# %%
test['predicted_score'] = gbm.predict(test_X)

# %%
test[['instance_id', 'predicted_score']].to_csv(config.data_prefix_path + 'sub0419_lightgbm.txt',sep=" ",index=False)

# %% [markdown]
# ## oof

# %%
from sklearn.model_selection import KFold
folds=KFold(n_splits=4,random_state=2018,shuffle=True)

# %%
del test
gc.collect()
# Out:
# 0

# %%
pred = np.zeros(len(train))
iters = 0

X_train = train[features].values
y_train = train['is_trade'].values

# %%
for n_fold,(trn_idx,val_idx) in enumerate(folds.split(X_train,y_train)):
    
    lgb_train = lgb.Dataset\
        (data=X_train[trn_idx], label=y_train[trn_idx],
         feature_name=features,categorical_feature=cat_features)
    
    lgb_eval = lgb.Dataset\
        (data=X_train[val_idx], label=y_train[val_idx],
         feature_name=features,categorical_feature=cat_features, reference=lgb_train)
    
    model = lgb.train(
        params = params,
        train_set = lgb_train,
        num_boost_round = 1000,
        valid_sets = [lgb_train,lgb_eval],
        early_stopping_rounds = 80,
        categorical_feature = cat_features,
        verbose_eval = 0)
    
    pred[val_idx] = model.predict(X_train[val_idx],num_iteration=model.best_iteration)
    loss = log_loss(y_train[val_idx],pred[val_idx])
    iters += model.best_iteration
    print("\t Fold %d : %.6f in %3d rounds" % (n_fold + 1, loss, model.best_iteration))

iters /= 4
print("平均迭代次数： "+str(iters))
train['is_trade'+'_oof'] = pred
# Out:
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\lightgbm\basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# 	 Fold 1 : 0.086073 in 459 rounds
# 	 Fold 2 : 0.087169 in 352 rounds
# 	 Fold 3 : 0.086706 in 398 rounds
# 	 Fold 4 : 0.086612 in 357 rounds
# 平均迭代次数： 416.5

# %%
# 保存结果,用作stacking
train[['instance_id', 'is_trade', 'is_trade'+'_oof']].to_csv(
    config.data_prefix_path + 'lightgbm_oof.txt',sep=" ",index=False
    )
